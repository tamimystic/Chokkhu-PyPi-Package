# %% [markdown]
# # Tabular Data Example
# This notebook demonstrates how to work with tabular data using Chokkhu.

# %%
import chokkhu
import pandas as pd
print('Chokkhu imported successfully!')
df = pd.read_csv('../tests/dummy_data/dummy_data.csv')
df.head()
